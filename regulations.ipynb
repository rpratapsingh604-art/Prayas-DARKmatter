# %%
import pandas as pd

regulations = {
    "id": [1, 2, 3, 4, 5, 6, 7, 8],

    "name": [
        "Digital Lending Framework",
        "Financial Data Protection Framework",
        "AI Credit Assessment Framework",
        "Cross Border Finance Framework",
        "Digital Payments Framework",
        "Digital Banking Framework",
        "Consumer Protection Framework",
        "Financial Cybersecurity Framework"
    ],

    "jurisdiction": [
        "India",
        "India",
        "India",
        "Singapore",
        "India",
        "India",
        "India",
        "India"
    ],

    "topic": [
        "Consumer Protection",
        "Data Privacy",
        "AI Governance",
        "Cross Border Finance",
        "Payments",
        "Digital Banking",
        "Consumer Protection",
        "Cybersecurity"
    ],

    "description": [
        "Rules covering digital lending and borrower protection",
        "Rules covering collection and processing of financial and personal data",
        "Guidelines for automated credit assessment and AI-based lending decisions",
        "Rules covering cross-border financial services and international transactions",
        "Rules covering digital payment providers and transaction security",
        "Rules covering digital banks and online banking services",
        "Rules concerning customer rights, disclosures and fair financial services",
        "Rules concerning cybersecurity, system security and protection of financial information"
    ]
}

regulations_df = pd.DataFrame(regulations)

regulations_df.to_csv("regulations.csv", index=False)

regulations_df
# Out:
#    id                                 name jurisdiction                 topic  \
# 0   1            Digital Lending Framework        India   Consumer Protection
# 1   2  Financial Data Protection Framework        India          Data Privacy
# 2   3       AI Credit Assessment Framework        India         AI Governance
# 3   4       Cross Border Finance Framework    Singapore  Cross Border Finance
# 4   5           Digital Payments Framework        India              Payments
# 5   6            Digital Banking Framework        India       Digital Banking
# 6   7        Consumer Protection Framework        India   Consumer Protection
# 7   8    Financial Cybersecurity Framework        India         Cybersecurity
#
#                                          description
# 0  Rules covering digital lending and borrower pr...
# 1  Rules covering collection and processing of fi...
# 2  Guidelines for automated credit assessment and...
# 3  Rules covering cross-border financial services...
# ...
