# %%
import pandas as pd

companies = {
    "id": [1, 2, 3, 4, 5],
    "name": ["FinLoan", "WalletX", "PayFlow", "CrediAI", "CloudBank"],
    "type": [
        "Fintech Lender",
        "Digital Wallet",
        "Payment Provider",
        "AI Lender",
        "Digital Bank"
    ],
    "country": ["India", "India", "Singapore", "India", "India"],
    "customers": [2000000, 5000000, 8000000, 1200000, 3500000],
    "products": [
        "AI Personal Loans",
        "Digital Payments",
        "Cross Border Payments",
        "AI Credit Scoring",
        "Digital Banking"
    ],
    "data_sources": [
        "Bank Transactions;Behavioral Data",
        "Transaction Data",
        "Transaction Data",
        "Behavioral Data;Device Data",
        "Transaction Data"
    ]
}

df = pd.DataFrame(companies)

df.to_csv("companies.csv", index=False)

df
# Out:
#    id       name              type    country  customers  \
# 0   1    FinLoan    Fintech Lender      India    2000000
# 1   2    WalletX    Digital Wallet      India    5000000
# 2   3    PayFlow  Payment Provider  Singapore    8000000
# 3   4    CrediAI         AI Lender      India    1200000
# 4   5  CloudBank      Digital Bank      India    3500000
#
#                 products                       data_sources
# 0      AI Personal Loans  Bank Transactions;Behavioral Data
# 1       Digital Payments                   Transaction Data
# 2  Cross Border Payments                   Transaction Data
# 3      AI Credit Scoring        Behavioral Data;Device Data
# 4        Digital Banking                   Transaction Data
