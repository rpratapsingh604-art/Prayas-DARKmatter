# %%
import pandas as pd

relationships = {
    "source": [
        "FinLoan",
        "FinLoan",
        "FinLoan",

        "WalletX",
        "WalletX",
        "WalletX",

        "PayFlow",
        "PayFlow",

        "CrediAI",
        "CrediAI",
        "CrediAI",

        "CloudBank",
        "CloudBank",

        "FinLoan",
        "CrediAI"
    ],

    "target": [
        "CloudBank",
        "PayFlow",
        "CrediAI",

        "PayFlow",
        "CloudBank",
        "FinLoan",

        "CloudBank",
        "WalletX",

        "CloudBank",
        "FinLoan",
        "PayFlow",

        "PayFlow",
        "WalletX",

        "WalletX",
        "PayFlow"
    ],

    "relationship": [
        "Banking Infrastructure",
        "Payment Provider",
        "Fintech Partnership",

        "Payment Provider",
        "Banking Infrastructure",
        "Fintech Partnership",

        "Banking Infrastructure",
        "Payment Network",

        "Banking Infrastructure",
        "Fintech Partnership",
        "Payment Provider",

        "Payment Network",
        "Digital Banking Partner",

        "Shared Customer Segment",
        "Shared Payment Infrastructure"
    ]
}

relationships_df = pd.DataFrame(relationships)

relationships_df.to_csv("relationships.csv", index=False)

relationships_df
# Out:
#        source     target                   relationship
# 0     FinLoan  CloudBank         Banking Infrastructure
# 1     FinLoan    PayFlow               Payment Provider
# 2     FinLoan    CrediAI            Fintech Partnership
# 3     WalletX    PayFlow               Payment Provider
# 4     WalletX  CloudBank         Banking Infrastructure
# 5     WalletX    FinLoan            Fintech Partnership
# 6     PayFlow  CloudBank         Banking Infrastructure
# 7     PayFlow    WalletX                Payment Network
# 8     CrediAI  CloudBank         Banking Infrastructure
# 9     CrediAI    FinLoan            Fintech Partnership
# 10    CrediAI    PayFlow               Payment Provider
# 11  CloudBank    PayFlow                Payment Network
# 12  CloudBank    WalletX        Digital Banking Partner
# 13    FinLoan    WalletX        Shared Customer Segment
# 14    CrediAI    PayFlow  Shared Payment Infrastructure
